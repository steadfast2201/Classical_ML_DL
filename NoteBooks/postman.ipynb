# %%
from docx import Document

# %%
doc = Document("C:\\Users\\aniket.patil\\Desktop\\Classical_ML\\Data\\WhatsApp ChatBot HIS  API - SRIT.docx")

# %%
# Extract all text
all_text = []
for para in doc.paragraphs:
    all_text.append(para.text)

# %%
# Join into one string
content = "\n".join(all_text)
print(content)
# Out:
# 1) Login API - GET API
# URL –
# For Gurgaon Login
# http://10.10.2.217:7777/rhis/j_mobile_security_check?j_username=chatbot_gurgaon&j_password=CKBirla@123&j_loginType=rhis
# For West Delhi Login
# http://10.10.2.217:7777/rhis/j_mobile_security_check?j_username=chatbot_west_delhi&j_password=CKBirla@123&j_loginType=rhis
#
# Response - {"login":" chatbot_gurgaon","hospitalId":2,"hospital":"CK Birla Hospital - Staging","departmentId":1,"departmentName":"ACCOUNTS AND FINANCE","serviceCenterId":7701,"serviceCenterName":"ACCOUNTS \u0026 FINANCE","sessionId":"1C0C52042087AFC8EA0FBCE178E16C0B"}
#
#
# 2) Registration API - POST API
# URL -  http://10.10.2.217:7777/rhis/df/whatsapp/registerPatient
# Payload - {"gender":"Female","patientName":"NARESH G","dob":"01/01/1998","emailId":"abc@g.com","siteId":2,"mobileNo":"9191919192"}
# Cookies - JSESSIONID=1C0C52042087AFC8EA0FBCE178E16C0B
# Response - {"mrn":"CKBHG0000226729","pdfBase64":"..."}
# 3) Payment API - POST API
# ...
