# %%
import pandas as pd

# %%
df = pd.read_json("/home/aniket/Classical_ML_DL/Data/brick-complexity-extractor/train_final.jsonl", lines=True)

# %%
df.to_csv("/home/aniket/Classical_ML_DL/Data/brick-complexity-extractor/train_final.csv", index=False)

# %%
df.head(10)
# Out:
#                                                 text   label
# 0  Request letter for salary statement for the pu...    easy
# 1               what are the four pillars of cooking    easy
# 2  Animals require water for survival, and where ...    easy
# 3  Write the following list of characters into a ...  medium
# 4  In the field of medical research, what steps c...    hard
# 5              What is the technology of the future?  medium
# 6  freeway 880 near oakland california, carpool l...    easy
# 7  The chief saw his entire tribe wiped out, he w...    easy
# 8  What happens next in this paragraph?\n\nHow to...  medium
# 9  Generate 4 sentence using the given words.\n\n...    easy
